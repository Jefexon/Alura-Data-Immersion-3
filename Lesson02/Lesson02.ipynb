# %%
#Importing pandas library.
import pandas as pd

#Assigning the dataframe url to a variable.
url_df = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"

#Assigning the uncompressed csv dataframe to a variable.
df = pd.read_csv(url_df, compression = 'zip')

#Renaming specific columns using rename(), for the purpose of translating it to English.
df.rename({'tratamento':'treatment', 'tempo':'duration', 'droga':'drug'}, axis=1, inplace=True)

#Renaming the contents of the column 'treatment', for the purpose of translating it to English.
df['treatment']= df['treatment'].replace({'com_droga':'with_drug', 'com_controle':'with_control'})

#Remove hyphen from column names
for column in df.columns:
    if '-' in column:
        index = column.find('-')
        changed_column = column[:index] + column[index+1:]
        df.rename({column:changed_column}, axis=1, inplace=True)
        
#Calling the dataframe.
df
# Out:
#                  id     treatment  duration dose       drug      g0      g1  \
# 0      id_000644bb2     with_drug        24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     with_drug        72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     with_drug        48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     with_drug        48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     with_drug        72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...       ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     with_drug        24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     with_drug        24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  with_control        48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     with_drug        24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     with_drug        72   D1  972f41291 -0.8598  1.0240
#
# ...

# %% [markdown]
# #### In the cell below they decided to change from drug to composite. They explain that it is no actually a drug, but more like small molecules.

# %%
mapa = {'drug': 'composite'}
df.rename(columns=mapa, inplace=True)
df.head()
# Out:
#              id  treatment  duration dose  composite      g0      g1      g2  \
# 0  id_000644bb2  with_drug        24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  with_drug        72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  with_drug        48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  with_drug        48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  with_drug        72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# #### Using Seaborn Library

# %%
composites = df['composite'].value_counts().index[:5]
composites
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
df.query('composite in @composites')
# Out:
#                  id     treatment  duration dose  composite      g0      g1  \
# 7      id_0020d0484     with_drug        48   D1  8b87a7a83  0.2711  0.5133
# 16     id_002fb9c19     with_drug        48   D1  87d714366  8.7380  0.1914
# 25     id_0054388ec  with_control        48   D1  cacb2b860 -0.6696 -0.2718
# 38     id_0079af0fb  with_control        24   D1  cacb2b860 -0.1636 -1.8230
# 40     id_007bfbb91  with_control        24   D2  cacb2b860 -1.3200 -1.7340
# ...             ...           ...       ...  ...        ...     ...     ...
# 23793  id_ffd26f361  with_control        48   D2  cacb2b860  0.6008  0.2781
# 23802  id_fff3976bd     with_drug        24   D1  87d714366  3.2890  2.1270
# 23805  id_fff6df1c5     with_drug        48   D2  5628cb3ee  1.7380 -1.2900
# 23811  id_fffc1c3f4  with_control        48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     with_drug        24   D1  8b87a7a83  0.6660  0.2324
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()#changes to seaborn default (believed to be a bug).

plt.figure(figsize=(8, 6))#changes the size of the graph (x, y).
ax = sns.countplot(x = 'composite', data=df.query('composite in @composites'))
ax.set_title('Top 5 Composite')
plt.show()

# %%
df['g0'].nunique()
# Out:
# 14367

# %%
df['g0'].min()
# Out:
# -5.513

# %%
df['g0'].max()
# Out:
# 10.0

# %%
df['g0'].hist(bins = 100)
# Out:
# <AxesSubplot:>

# %%
df['g19'].hist(bins = 100)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#            duration            g0            g1            g2            g3  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean      48.020156      0.248366     -0.095684      0.152253      0.081971
# std       19.402807      1.393399      0.812363      1.035731      0.950012
# min       24.000000     -5.513000     -5.737000     -9.104000     -5.998000
# 25%       24.000000     -0.473075     -0.562200     -0.437750     -0.429575
# 50%       48.000000     -0.008850     -0.046600      0.075200      0.008050
# 75%       72.000000      0.525700      0.403075      0.663925      0.463400
# max       72.000000     10.000000      5.039000      8.257000     10.000000
#
#                  g4            g5            g6            g7            g8  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean       0.057347     -0.138836      0.035961     -0.202651     -0.190083
# ...

# %%
df.loc[:, 'g0':'g771'].describe()
# Out:
#                  g0            g1            g2            g3            g4  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean       0.248366     -0.095684      0.152253      0.081971      0.057347
# std        1.393399      0.812363      1.035731      0.950012      1.032091
# min       -5.513000     -5.737000     -9.104000     -5.998000     -6.369000
# 25%       -0.473075     -0.562200     -0.437750     -0.429575     -0.470925
# 50%       -0.008850     -0.046600      0.075200      0.008050     -0.026900
# 75%        0.525700      0.403075      0.663925      0.463400      0.465375
# max       10.000000      5.039000      8.257000     10.000000     10.000000
#
#                  g5            g6            g7            g8            g9  \
# count  23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# mean      -0.138836      0.035961     -0.202651     -0.190083      0.119905
# ...

# %% [markdown]
# #### The cell bellow changes the rows with the columns

# %%
df.loc[:, 'g0':'g771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
df.loc[:, 'g0':'g771'].describe().T['mean'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 'c' stand for a type of cell (e.g. cancer cells, health cells etc...). The purpose is to try the same drug or composite in different cells.

# %%
df.loc[:, 'c0':'c99'].describe().T['mean'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plotting a boxplot!

# %%
sns.boxplot(x='g0', data=df)
# Out:
# <AxesSubplot:xlabel='g0'>

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(y='g0', x='treatment', data=df)
# Out:
# <AxesSubplot:xlabel='treatment', ylabel='g0'>

# %% [markdown]
# ## Challenges!
#
# ### Challenge 01: Sort the chart
#
# ### Challenge 02: Improve the visualization of the chart (e.g. font size...)
#
# ### Challenge 03: Plot the histograms with Seaborn
#
# ### Challenge 04: Study the statistics of .describe(), (e.g. std, 50%...)
#
# ### Challenge 05: Reflect on the manipulation of the size of visualizations.
#
# ### Challenge 06: Do more analysis with boxplot and histogram.
#
# ### Challenge 07: Summary of lesson.
