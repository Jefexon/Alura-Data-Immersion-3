# %%
import pandas as pd

df = pd.read_csv('data_experiments.csv')

# %%
df.head()
# Out:
#    Unnamed: 0            id  treatment  duration dose  composite      g0  \
# 0           0  id_000644bb2  with_drug        24   D1  b68db1d53  1.0620
# 1           1  id_000779bfc  with_drug        72   D1  df89a8e5a  0.0743
# 2           2  id_000a6266a  with_drug        48   D1  18bb41b2c  0.6280
# 3           3  id_0015fd391  with_drug        48   D1  8c7f86626 -0.5138
# 4           4  id_001626bd3  with_drug        72   D2  7cbed3131 -0.3254
#
#        g1      g2      g3  ...     c90     c91     c92     c93     c94  \
# 0  0.5577 -0.2479 -0.6208  ...  0.2862  0.2584  0.8076  0.5523 -0.1912
# 1  0.4087  0.2991  0.0604  ... -0.4265  0.7543  0.4708  0.0230  0.2957
# 2  0.5817  1.5540 -0.0764  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240
# 3 -0.2491 -0.2656  0.5288  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632
# 4 -0.4009  0.9700  0.6919  ...  0.0042  0.0048  0.6670  1.0690  0.5523
#
#       c95     c96     c97     c98     c99
# 0  0.6584 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#              id  treatment  duration dose  composite      g0      g1      g2  \
# 0  id_000644bb2  with_drug        24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  with_drug        72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  with_drug        48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  with_drug        48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  with_drug        72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
df.to_csv('data_experiments1.csv', index=False)

# %%
df1 = pd.read_csv('data_experiments1.csv')

# %%
df1.head()
# Out:
#              id  treatment  duration dose  composite      g0      g1      g2  \
# 0  id_000644bb2  with_drug        24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  with_drug        72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  with_drug        48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  with_drug        48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  with_drug        72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...
