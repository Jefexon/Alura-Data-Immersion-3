# %%
#Importing pandas library.
import pandas as pd

#Assigning the dataframe url to a variable.
url_df = "https://github.com/Jefexon/Alura-Data-Immersion-3/blob/main/Data/data_experiments.zip?raw=true"

#Assigning the uncompressed csv dataframe to a variable.
df = pd.read_csv(url_df, compression = 'zip')

# %%
#Calling the dataframe.
df
# Out:
#        Unnamed: 0            id     treatment  duration dose  composite  \
# 0               0  id_000644bb2     with_drug        24   D1  b68db1d53
# 1               1  id_000779bfc     with_drug        72   D1  df89a8e5a
# 2               2  id_000a6266a     with_drug        48   D1  18bb41b2c
# 3               3  id_0015fd391     with_drug        48   D1  8c7f86626
# 4               4  id_001626bd3     with_drug        72   D2  7cbed3131
# ...           ...           ...           ...       ...  ...        ...
# 23809       23809  id_fffb1ceed     with_drug        24   D2  df1d0a5a1
# 23810       23810  id_fffb70c0c     with_drug        24   D2  ecf3b6b74
# 23811       23811  id_fffc1c3f4  with_control        48   D2  cacb2b860
# 23812       23812  id_fffcb9e7c     with_drug        24   D1  8b87a7a83
# 23813       23813  id_ffffdd77b     with_drug        72   D1  972f41291
#
#            g0      g1      g2      g3  ...     c90     c91     c92     c93  \
# 0      1.0620  0.5577 -0.2479 -0.6208  ...  0.2862  0.2584  0.8076  0.5523
# 1      0.0743  0.4087  0.2991  0.0604  ... -0.4265  0.7543  0.4708  0.0230
# 2      0.6280  0.5817  1.5540 -0.0764  ... -0.7250 -0.6297  0.6103  0.0223
# 3     -0.5138 -0.2491 -0.2656  0.5288  ... -2.0990 -0.6441 -5.6300 -1.3780
# 4     -0.3254 -0.4009  0.9700  0.6919  ...  0.0042  0.0048  0.6670  1.0690
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23809  0.1394 -0.0636 -0.1112 -0.5080  ...  0.1969  0.0262 -0.8121  0.3434
# 23810 -1.3260  0.3478 -0.3743  0.9905  ...  0.4286  0.4426  0.0423 -0.3195
# 23811  0.3942  0.3756  0.3109 -0.7389  ...  0.5409  0.3755  0.7343  0.2807
# 23812  0.6660  0.2324  0.4392  0.2044  ... -0.1105  0.4258 -0.2012  0.1506
# 23813 -0.8598  1.0240 -0.1361  0.7952  ... -3.3890 -1.7450 -6.6300 -4.0950
#
#           c94     c95     c96     c97     c98     c99
# 0     -0.1912  0.6584 -0.3981  0.2139  0.3801  0.4176
# 1      0.2957  0.4899  0.1522  0.1241  0.6077  0.7371
# 2     -1.3240 -0.3174 -0.6417 -0.2187 -1.4080  0.6931
# 3     -0.8632 -1.2880 -1.6210 -0.8784 -0.3876 -0.8154
# 4      0.5523 -0.3031  0.1094  0.2885 -0.3786  0.7125
# ...       ...     ...     ...     ...     ...     ...
# 23809  0.5372 -0.3246  0.0631  0.9171  0.5258  0.4680
# 23810 -0.8086 -0.9798 -0.2084 -0.1224 -0.2715  0.3689
# 23811  0.4116  0.6422  0.2256  0.7592  0.6656  0.3808
# 23812  1.5230  0.7101  0.1732  0.7015 -0.6290  0.0740
# 23813 -7.3860 -1.4160 -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 878 columns]
